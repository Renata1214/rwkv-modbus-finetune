# %%
import os
import torch
import json
import sys


os.environ["CUDA_VISIBLE_DEVICES"] = "1"  # Replace 1 with the GPU index you want
print(torch.cuda.get_device_name(0))  # This will now refer to GPU 1 as "GPU 0" in the notebook context
print(torch.cuda.is_available())

print("Device count:", torch.cuda.device_count())
print("Current GPU:", torch.cuda.current_device())
print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# NVIDIA A100-SXM4-80GB
# True
# Device count: 1
# Current GPU: 0
# GPU name: NVIDIA A100-SXM4-80GB

# %%
input_path = "/home/re2230/Project1_RWKV_FINETUNING/modbus_dataset.jsonl"
output_path = "/home/re2230/Project1_RWKV_FINETUNING/modbus_dataset_rwkv.jsonl"

with open(input_path, "r") as infile, open(output_path, "w") as outfile:
    for line in infile:
        item = json.loads(line)
        prompt = f"query: {item['query']}\n\nresponse: {item['response']}"
        outfile.write(json.dumps({"text": prompt}) + "\n")

# %%
from huggingface_hub import hf_hub_download

model_path = hf_hub_download(
    repo_id="RWKV/rwkv-5-world-all-pth",
    filename="RWKV-5-World-0.4B-v2-20231113-ctx4096.pth"
)

print(f"Model downloaded to: {model_path}")
# Out:
# Model downloaded to: /home/re2230/.cache/huggingface/hub/models--RWKV--rwkv-5-world-all-pth/snapshots/d48d1c54cf32cfdc13fca3c767998a0bf3eef8b6/RWKV-5-World-0.4B-v2-20231113-ctx4096.pth

# %%
model_path = "/home/re2230/.cache/huggingface/hub/models--RWKV--rwkv-5-world-all-pth/snapshots/d48d1c54cf32cfdc13fca3c767998a0bf3eef8b6/RWKV-5-World-0.4B-v2-20231113-ctx4096.pth"

# %%
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: re2230 (re2230-new-york-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# Paths to input files
modbus_path = "/home/re2230/Project1_RWKV_FINETUNING/modbus_dataset.jsonl"
modbusa_test_path = "//home/re2230/Project1_RWKV_FINETUNING/modbus_dataset_test.jsonl"
output_path = "/home/re2230/Project1_RWKV_FINETUNING/combined_modbus_dataset.jsonl"

# Read the first dataset
with open(modbus_path, "r") as f:
    modbus_data = [json.loads(line) for line in f]

# Read the second dataset (only lines 21 to 50)
with open(modbusa_test_path, "r") as f:
    modbusa_lines = f.readlines()[20:159]  # lines 21 to 160 (0-indexed)
    modbusa_data = [json.loads(line) for line in modbusa_lines]

# Combine datasets
combined_data = modbus_data + modbusa_data

# Write to new file
with open(output_path, "w") as f:
    for entry in combined_data:
        f.write(json.dumps(entry) + "\n")

print(f"✅ Combined dataset written to {output_path}")
# Out:
# ✅ Combined dataset written to /home/re2230/combined_modbus_dataset.jsonl

# %%
input_path = "/home/re2230/Project1_RWKV_FINETUNING/combined_modbus_dataset.jsonl"
output_path = "/home/re2230/Project1_RWKV_FINETUNING/combined_modbus_dataset_rwkv.jsonl"

with open(input_path, "r") as infile, open(output_path, "w") as outfile:
    for line in infile:
        item = json.loads(line)
        prompt = f"query: {item['query']}\n\nresponse: {item['response']}"
        outfile.write(json.dumps({"text": prompt}) + "\n")

# %%
#TRAINING WITH JSONL FORMAT
from datasets import load_dataset
import subprocess
import shlex

#  Weights & Biases
os.environ["WANDB_PROJECT"] = "rwkv-finetune"

model_path = "/home/re2230/.cache/huggingface/hub/models--RWKV--rwkv-5-world-all-pth/snapshots/d48d1c54cf32cfdc13fca3c767998a0bf3eef8b6/RWKV-5-World-0.4B-v2-20231113-ctx4096.pth"

command = f"""
python RWKV-PEFT/train.py \
--load_model {model_path} \
--data_file /home/re2230/Project1_RWKV_FINETUNING/combined_modbus_dataset_rwkv.jsonl \
--data_type jsonl \
--sft_field text \
--ctx_len 512 \
--epoch_steps 50 \
--epoch_count 50 \
--micro_bsz 1 \
--n_layer 24 \
--n_embd 1024 \
--vocab_size 65536 \
--lr_init 6e-5 \
--warmup_steps 10 \
--strategy deepspeed \
--accelerator cuda \
--precision bf16 \
--peft disha \
--disha_config '{{"mode":"bone","r":32,"load":""}}' \
--proj_dir /home/re2230/Project1_RWKV_FINETUNING/out/rwkv-modbus-ft
"""


result = subprocess.run(shlex.split(command), capture_output=True, text=True)

print("📤 STDOUT:\n", result.stdout)
print("⚠️ STDERR:\n", result.stderr)

if result.returncode != 0:
    print(f"❌ Training failed with exit code {result.returncode}")
else:
    print("✅ Training started successfully")  


#Not combined dataset : Metric val_loss improved by 0.050 >= min_delta = 0.001. New best score: 1.228
#Monitored metric val_loss did not improve in the last 3 records. Best score: 1.228. Signaling Trainer to stop.
# Out:
# 📤 STDOUT:
#  [2025-06-10 04:54:22,553] [INFO] [real_accelerator.py:110:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# ########## WKV OP           cuda               ##########
# ########## WKV OP           cuda               ##########
# ########## WKV OP           cuda               ##########
#
# ########## FUSED OP    False          ##########
# ########## FUSED OP    False          ##########
# ########## FUSED OP    False          ##########
#
# RWKV_MY_TESTING x052
# ninja: no work to do.
# RWKV(
#   (model): RWKV5(
#     (emb): Embedding(65536, 1024)
#     (blocks): ModuleList(
#       (0): Block(
#         (ln1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (ln2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (ln0): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (att): RWKV_TimeMix_RWKV5(
#           (time_shift): ZeroPad2d((0, 0, 1, -1))
#           (receptance): BoneLinear()
#           (key): BoneLinear()
#           (value): BoneLinear()
#           (output): BoneLinear()
#           (gate): BoneLinear()
#           (ln_x): GroupNorm(16, 1024, eps=1e-05, affine=True)
#         )
#         (ffn): RWKV_ChannelMix(
#           (time_shift): ZeroPad2d((0, 0, 1, -1))
#           (key): BoneLinear()
#           (receptance): BoneLinear()
#           (value): BoneLinear()
#         )
#       )
#       (1-23): 23 x Block(
#         (ln1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (ln2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (att): RWKV_TimeMix_RWKV5(
#           (time_shift): ZeroPad2d((0, 0, 1, -1))
#           (receptance): BoneLinear()
#           (key): BoneLinear()
#           (value): BoneLinear()
#           (output): BoneLinear()
#           (gate): BoneLinear()
#           (ln_x): GroupNorm(16, 1024, eps=1e-05, affine=True)
#         )
#         (ffn): RWKV_ChannelMix(
#           (time_shift): ZeroPad2d((0, 0, 1, -1))
#           (key): BoneLinear()
#           (receptance): BoneLinear()
#           (value): BoneLinear()
#         )
#       )
#     )
#     (ln_out): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (head): Linear(in_features=1024, out_features=65536, bias=False)
#   )
#   (criterion): CrossEntropyLoss()
# )
# [2025-06-10 04:54:27,936] [WARNING] [comm.py:152:init_deepspeed_backend] NCCL backend in DeepSpeed not yet implemented
# ninja: no work to do.
# Time to load fused_adam op: 0.05607724189758301 seconds
# Rank: 0 partition count [1, 1] and sizes[(8581120, False), (24576, False)]
#
# Training: |          | 0/? [00:00<?, ?it/s]
# Training:   0%|          | 0/45 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/45 [00:00<?, ?it/s]
# {'zero_allow_untested_optimizer': True, 'zero_optimization': {'stage': 2, 'contiguous_gradients': True, 'overlap_comm': True, 'allgather_partitions': True, 'reduce_scatter': True, 'allgather_bucket_size': 200000000, 'reduce_bucket_size': 200000000, 'sub_group_size': 1000000000000}, 'activation_checkpointing': {'partition_activations': False, 'cpu_checkpointing': False, 'contiguous_memory_optimization': False, 'synchronize_checkpoint_boundary': False}, 'aio': {'block_size': 1048576, 'queue_depth': 8, 'single_submit': False, 'overlap_events': True, 'thread_count': 1}, 'gradient_accumulation_steps': 1, 'train_micro_batch_size_per_gpu': 1, 'gradient_clipping': 1.0, 'bf16': {'enabled': True}}
#
#
# Epoch 0:   2%|▏         | 1/45 [00:01<00:51,  0.85it/s]
# Epoch 0:   2%|▏         | 1/45 [00:01<00:51,  0.85it/s, lr=6e-5, sum_loss=3.480, loss=3.480]
# Epoch 0:   4%|▍         | 2/45 [00:01<00:30,  1.42it/s, lr=6e-5, sum_loss=3.480, loss=3.480]
# Epoch 0:   4%|▍         | 2/45 [00:01<00:30,  1.42it/s, lr=6e-5, sum_loss=3.220, loss=2.970, REAL it/s=4.250, Kt/s=2.180]
# Epoch 0:   7%|▋         | 3/45 [00:01<00:22,  1.86it/s, lr=6e-5, sum_loss=3.220, loss=2.970, REAL it/s=4.250, Kt/s=2.180]
# Epoch 0:   7%|▋         | 3/45 [00:01<00:22,  1.86it/s, lr=5.98e-5, sum_loss=3.230, loss=3.270, REAL it/s=4.740, Kt/s=2.430]
# Epoch 0:   9%|▉         | 4/45 [00:01<00:18,  2.17it/s, lr=5.98e-5, sum_loss=3.230, loss=3.270, REAL it/s=4.740, Kt/s=2.430]
# Epoch 0:   9%|▉         | 4/45 [00:01<00:18,  2.17it/s, lr=5.96e-5, sum_loss=3.060, loss=2.560, REAL it/s=4.420, Kt/s=2.260]
# Epoch 0:  11%|█         | 5/45 [00:02<00:16,  2.42it/s, lr=5.96e-5, sum_loss=3.060, loss=2.560, REAL it/s=4.420, Kt/s=2.260]
# Epoch 0:  11%|█         | 5/45 [00:02<00:16,  2.42it/s, lr=5.92e-5, sum_loss=2.880, loss=2.110, REAL it/s=4.490, Kt/s=2.300]
# Epoch 0:  13%|█▎        | 6/45 [00:02<00:14,  2.62it/s, lr=5.92e-5, sum_loss=2.880, loss=2.110, REAL it/s=4.490, Kt/s=2.300]
# Epoch 0:  13%|█▎        | 6/45 [00:02<00:14,  2.62it/s, lr=5.88e-5, sum_loss=2.860, loss=2.720, REAL it/s=4.420, Kt/s=2.260]
# Epoch 0:  16%|█▌        | 7/45 [00:02<00:13,  2.79it/s, lr=5.88e-5, sum_loss=2.860, loss=2.720, REAL it/s=4.420, Kt/s=2.260]
# Epoch 0:  16%|█▌        | 7/45 [00:02<00:13,  2.79it/s, lr=5.82e-5, sum_loss=2.860, loss=2.940, REAL it/s=4.590, Kt/s=2.350]
# Epoch 0:  76%|███████▌  | 34/45 [00:08<00:02,  4.06it/s, lr=2.44e-5, sum_loss=2.280, loss=2.030, REAL it/s=4.680, Kt/s=2.400]
# Epoch 0:  76%|███████▌  | 34/45 [00:08<00:02,  4.06it/s, lr=2.3e-5, sum_loss=2.280, loss=1.990, REAL it/s=4.780, Kt/s=2.450]
# Epoch 0:  78%|███████▊  | 35/45 [00:08<00:02,  4.08it/s, lr=2.3e-5, sum_loss=2.280, loss=1.990, REAL it/s=4.780, Kt/s=2.450]
# Epoch 0:  78%|███████▊  | 35/45 [00:08<00:02,  4.08it/s, lr=2.16e-5, sum_loss=2.270, loss=2.220, REAL it/s=4.720, Kt/s=2.420]
# Epoch 0:  80%|████████  | 36/45 [00:08<00:02,  4.09it/s, lr=2.16e-5, sum_loss=2.270, loss=2.220, REAL it/s=4.720, Kt/s=2.420]
# Epoch 0:  80%|████████  | 36/45 [00:08<00:02,  4.09it/s, lr=2.03e-5, sum_loss=2.280, loss=2.310, REAL it/s=4.710, Kt/s=2.410]
# Epoch 0:  82%|████████▏ | 37/45 [00:09<00:01,  4.10it/s, lr=2.03e-5, sum_loss=2.280, loss=2.310, REAL it/s=4.710, Kt/s=2.410]
# Epoch 0:  82%|████████▏ | 37/45 [00:09<00:01,  4.10it/s, lr=1.91e-5, sum_loss=2.250, loss=1.570, REAL it/s=4.520, Kt/s=2.310]
# Epoch 0:  84%|████████▍ | 38/45 [00:09<00:01,  4.12it/s, lr=1.91e-5, sum_loss=2.250, loss=1.570, REAL it/s=4.520, Kt/s=2.310]
# Epoch 0:  84%|████████▍ | 38/45 [00:09<00:01,  4.12it/s, lr=1.79e-5, sum_loss=2.230, loss=1.440, REAL it/s=4.770, Kt/s=2.440]
# Epoch 0:  87%|████████▋ | 39/45 [00:09<00:01,  4.13it/s, lr=1.79e-5, sum_loss=2.230, loss=1.440, REAL it/s=4.770, Kt/s=2.440]
# Epoch 0:  87%|████████▋ | 39/45 [00:09<00:01,  4.13it/s, lr=1.68e-5, sum_loss=2.250, loss=2.440, REAL it/s=4.460, Kt/s=2.280]
# Epoch 0:  89%|████████▉ | 40/45 [00:09<00:01,  4.14it/s, lr=1.68e-5, sum_loss=2.250, loss=2.440, REAL it/s=4.460, Kt/s=2.280]
# Epoch 0:  89%|████████▉ | 40/45 [00:09<00:01,  4.14it/s, lr=1.57e-5, sum_loss=2.220, loss=1.270, REAL it/s=4.700, Kt/s=2.410]
# Epoch 0:  91%|█████████ | 41/45 [00:09<00:00,  4.15it/s, lr=1.57e-5, sum_loss=2.220, loss=1.270, REAL it/s=4.700, Kt/s=2.410]
# Epoch 0:  91%|█████████ | 41/45 [00:09<00:00,  4.15it/s, lr=1.48e-5, sum_loss=2.200, loss=1.560, REAL it/s=4.890, Kt/s=2.510]
# Epoch 0:  93%|█████████▎| 42/45 [00:10<00:00,  4.17it/s, lr=1.48e-5, sum_loss=2.200, loss=1.560, REAL it/s=4.890, Kt/s=2.510]
# Epoch 0:  93%|█████████▎| 42/45 [00:10<00:00,  4.17it/s, lr=1.39e-5, sum_loss=2.190, loss=1.650, REAL it/s=4.810, Kt/s=2.460]
# Epoch 0:  96%|█████████▌| 43/45 [00:10<00:00,  4.18it/s, lr=1.39e-5, sum_loss=2.190, loss=1.650, REAL it/s=4.810, Kt/s=2.460]
# Epoch 0:  96%|█████████▌| 43/45 [00:10<00:00,  4.18it/s, lr=1.31e-5, sum_loss=2.170, loss=1.700, REAL it/s=4.890, Kt/s=2.500]
# Epoch 0:  98%|█████████▊| 44/45 [00:10<00:00,  4.20it/s, lr=1.31e-5, sum_loss=2.170, loss=1.700, REAL it/s=4.890, Kt/s=2.500]
# Epoch 0:  98%|█████████▊| 44/45 [00:10<00:00,  4.20it/s, lr=1.24e-5, sum_loss=2.170, loss=2.120, REAL it/s=4.840, Kt/s=2.480]
# Epoch 0: 100%|██████████| 45/45 [00:10<00:00,  4.21it/s, lr=1.24e-5, sum_loss=2.170, loss=2.120, REAL it/s=4.840, Kt/s=2.480]
# Epoch 0: 100%|██████████| 45/45 [00:10<00:00,  4.21it/s, lr=1.18e-5, sum_loss=2.160, loss=1.620, REAL it/s=4.790, Kt/s=2.450]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 18.80it/s]
#
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 20.78it/s]
#
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 21.40it/s]
#
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 22.01it/s]
#
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 22.21it/s]
#
#
# Epoch 0: 100%|██████████| 45/45 [00:11<00:00,  4.07it/s, lr=1.18e-5, sum_loss=2.160, loss=1.620, REAL it/s=4.790, Kt/s=2.450, val_loss=1.780]
# Epoch 0: 100%|██████████| 45/45 [00:11<00:00,  4.04it/s, lr=1.18e-5, sum_loss=2.160, loss=1.620, REAL it/s=4.790, Kt/s=2.450, val_loss=1.780]
# Epoch 0:   0%|          | 0/45 [00:00<?, ?it/s, lr=1.18e-5, sum_loss=2.160, loss=1.620, REAL it/s=4.790, Kt/s=2.450, val_loss=1.780]
# Epoch 1:   0%|          | 0/45 [00:00<?, ?it/s, lr=1.18e-5, sum_loss=2.160, loss=1.620, REAL it/s=4.790, Kt/s=2.450, val_loss=1.780]
# Epoch 1:   2%|▏         | 1/45 [00:00<00:20,  2.10it/s, lr=1.18e-5, sum_loss=2.160, loss=1.620, REAL it/s=4.790, Kt/s=2.450, val_loss=1.780]
# Epoch 1:   2%|▏         | 1/45 [00:00<00:21,  2.09it/s, lr=1.12e-5, sum_loss=2.220, loss=2.220, REAL it/s=1.070, Kt/s=0.550, val_loss=1.780]
# Epoch 1:   4%|▍         | 2/45 [00:00<00:15,  2.83it/s, lr=1.12e-5, sum_loss=2.220, loss=2.220, REAL it/s=1.070, Kt/s=0.550, val_loss=1.780]
# Epoch 1:   4%|▍         | 2/45 [00:00<00:15,  2.83it/s, lr=1.08e-5, sum_loss=1.980, loss=1.740, REAL it/s=4.330, Kt/s=2.220, val_loss=1.780]
# Epoch 1:   7%|▋         | 3/45 [00:00<00:12,  3.24it/s, lr=1.08e-5, sum_loss=1.980, loss=1.740, REAL it/s=4.330, Kt/s=2.220, val_loss=1.780]
# Epoch 1:   7%|▋         | 3/45 [00:00<00:12,  3.24it/s, lr=1.04e-5, sum_loss=1.960, loss=1.910, REAL it/s=4.530, Kt/s=2.320, val_loss=1.780]
# Epoch 1:  80%|████████  | 36/45 [00:08<00:02,  4.33it/s, lr=1e-5, sum_loss=1.630, loss=1.790, REAL it/s=4.780, Kt/s=2.450, val_loss=1.780]
# Epoch 1:  82%|████████▏ | 37/45 [00:08<00:01,  4.34it/s, lr=1e-5, sum_loss=1.630, loss=1.790, REAL it/s=4.780, Kt/s=2.450, val_loss=1.780]
# Epoch 1:  82%|████████▏ | 37/45 [00:08<00:01,  4.34it/s, lr=1e-5, sum_loss=1.620, loss=1.380, REAL it/s=4.580, Kt/s=2.340, val_loss=1.780]
# Epoch 1:  84%|████████▍ | 38/45 [00:08<00:01,  4.35it/s, lr=1e-5, sum_loss=1.620, loss=1.380, REAL it/s=4.580, Kt/s=2.340, val_loss=1.780]
# Epoch 1:  84%|████████▍ | 38/45 [00:08<00:01,  4.35it/s, lr=1e-5, sum_loss=1.620, loss=1.380, REAL it/s=4.730, Kt/s=2.420, val_loss=1.780]
# Epoch 1:  87%|████████▋ | 39/45 [00:08<00:01,  4.35it/s, lr=1e-5, sum_loss=1.620, loss=1.380, REAL it/s=4.730, Kt/s=2.420, val_loss=1.780]
# Epoch 1:  87%|████████▋ | 39/45 [00:08<00:01,  4.35it/s, lr=1e-5, sum_loss=1.620, loss=1.640, REAL it/s=4.370, Kt/s=2.240, val_loss=1.780]
# Epoch 1:  89%|████████▉ | 40/45 [00:09<00:01,  4.35it/s, lr=1e-5, sum_loss=1.620, loss=1.640, REAL it/s=4.370, Kt/s=2.240, val_loss=1.780]
# Epoch 1:  89%|████████▉ | 40/45 [00:09<00:01,  4.35it/s, lr=1e-5, sum_loss=1.620, loss=1.520, REAL it/s=4.610, Kt/s=2.360, val_loss=1.780]
# Epoch 1:  91%|█████████ | 41/45 [00:09<00:00,  4.36it/s, lr=1e-5, sum_loss=1.620, loss=1.520, REAL it/s=4.610, Kt/s=2.360, val_loss=1.780]
# Epoch 1:  91%|█████████ | 41/45 [00:09<00:00,  4.36it/s, lr=1e-5, sum_loss=1.630, loss=1.780, REAL it/s=4.680, Kt/s=2.390, val_loss=1.780]
# Epoch 1:  93%|█████████▎| 42/45 [00:09<00:00,  4.36it/s, lr=1e-5, sum_loss=1.630, loss=1.780, REAL it/s=4.680, Kt/s=2.390, val_loss=1.780]
# Epoch 1:  93%|█████████▎| 42/45 [00:09<00:00,  4.36it/s, lr=1e-5, sum_loss=1.620, loss=1.060, REAL it/s=4.400, Kt/s=2.250, val_loss=1.780]
# Epoch 1:  96%|█████████▌| 43/45 [00:09<00:00,  4.37it/s, lr=1e-5, sum_loss=1.620, loss=1.060, REAL it/s=4.400, Kt/s=2.250, val_loss=1.780]
# Epoch 1:  96%|█████████▌| 43/45 [00:09<00:00,  4.37it/s, lr=1e-5, sum_loss=1.620, loss=1.750, REAL it/s=4.660, Kt/s=2.390, val_loss=1.780]
# Epoch 1:  98%|█████████▊| 44/45 [00:10<00:00,  4.38it/s, lr=1e-5, sum_loss=1.620, loss=1.750, REAL it/s=4.660, Kt/s=2.390, val_loss=1.780]
# Epoch 1:  98%|█████████▊| 44/45 [00:10<00:00,  4.38it/s, lr=1e-5, sum_loss=1.630, loss=2.190, REAL it/s=4.770, Kt/s=2.440, val_loss=1.780]
# Epoch 1: 100%|██████████| 45/45 [00:10<00:00,  4.38it/s, lr=1e-5, sum_loss=1.630, loss=2.190, REAL it/s=4.770, Kt/s=2.440, val_loss=1.780]
# Epoch 1: 100%|██████████| 45/45 [00:10<00:00,  4.38it/s, lr=1e-5, sum_loss=1.640, loss=1.820, REAL it/s=4.450, Kt/s=2.280, val_loss=1.780]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 19.61it/s]
#
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 21.67it/s]
#
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 22.38it/s]
#
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 22.99it/s]
#
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 23.40it/s]
#
#
# Epoch 1: 100%|██████████| 45/45 [00:10<00:00,  4.20it/s, lr=1e-5, sum_loss=1.640, loss=1.820, REAL it/s=4.450, Kt/s=2.280, val_loss=1.590]
# Epoch 1: 100%|██████████| 45/45 [00:10<00:00,  4.20it/s, lr=1e-5, sum_loss=1.640, loss=1.820, REAL it/s=4.450, Kt/s=2.280, val_loss=1.590]
# Epoch 1:   0%|          | 0/45 [00:00<?, ?it/s, lr=1e-5, sum_loss=1.640, loss=1.820, REAL it/s=4.450, Kt/s=2.280, val_loss=1.590]
# Epoch 2:   0%|          | 0/45 [00:00<?, ?it/s, lr=1e-5, sum_loss=1.640, loss=1.820, REAL it/s=4.450, Kt/s=2.280, val_loss=1.590]
# Epoch 2:   2%|▏         | 1/45 [00:00<00:21,  2.02it/s, lr=1e-5, sum_loss=1.640, loss=1.820, REAL it/s=4.450, Kt/s=2.280, val_loss=1.590]
# Epoch 2:   2%|▏         | 1/45 [00:00<00:21,  2.02it/s, lr=1e-5, sum_loss=0.980, loss=0.980, REAL it/s=1.080, Kt/s=0.555, val_loss=1.590]
# Epoch 2:   4%|▍         | 2/45 [00:00<00:15,  2.82it/s, lr=1e-5, sum_loss=0.980, loss=0.980, REAL it/s=1.080, Kt/s=0.555, val_loss=1.590]
# Epoch 2:   4%|▍         | 2/45 [00:00<00:15,  2.82it/s, lr=1e-5, sum_loss=1.360, loss=1.730, REAL it/s=4.630, Kt/s=2.370, val_loss=1.590]
# Epoch 2:   7%|▋         | 3/45 [00:00<00:12,  3.28it/s, lr=1e-5, sum_loss=1.360, loss=1.730, REAL it/s=4.630, Kt/s=2.370, val_loss=1.590]
# Epoch 2:   7%|▋         | 3/45 [00:00<00:12,  3.28it/s, lr=1e-5, sum_loss=1.440, loss=1.590, REAL it/s=4.850, Kt/s=2.480, val_loss=1.590]
# Epoch 2:   9%|▉         | 4/45 [00:01<00:11,  3.54it/s, lr=1e-5, sum_loss=1.440, loss=1.590, REAL it/s=4.850, Kt/s=2.480, val_loss=1.590]
# Epoch 2:   9%|▉         | 4/45 [00:01<00:11,  3.54it/s, lr=1e-5, sum_loss=1.410, loss=1.340, REAL it/s=4.690, Kt/s=2.400, val_loss=1.590]
# Epoch 2:  11%|█         | 5/45 [00:01<00:10,  3.74it/s, lr=1e-5, sum_loss=1.410, loss=1.340, REAL it/s=4.690, Kt/s=2.400, val_loss=1.590]

#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 19.12it/s]
#
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 18.75it/s]
#
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 19.40it/s]
#
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 19.66it/s]
#
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 19.95it/s]
#
#
# Epoch 2: 100%|██████████| 45/45 [00:10<00:00,  4.40it/s, lr=1e-5, sum_loss=1.450, loss=1.770, REAL it/s=4.690, Kt/s=2.400, val_loss=1.460]
# Epoch 2: 100%|██████████| 45/45 [00:10<00:00,  4.40it/s, lr=1e-5, sum_loss=1.450, loss=1.770, REAL it/s=4.690, Kt/s=2.400, val_loss=1.460]
# Epoch 2:   0%|          | 0/45 [00:00<?, ?it/s, lr=1e-5, sum_loss=1.450, loss=1.770, REAL it/s=4.690, Kt/s=2.400, val_loss=1.460]
# Epoch 3:   0%|          | 0/45 [00:00<?, ?it/s, lr=1e-5, sum_loss=1.450, loss=1.770, REAL it/s=4.690, Kt/s=2.400, val_loss=1.460]
# Epoch 3:   2%|▏         | 1/45 [00:00<00:19,  2.23it/s, lr=1e-5, sum_loss=1.450, loss=1.770, REAL it/s=4.690, Kt/s=2.400, val_loss=1.460]
# Epoch 3:   2%|▏         | 1/45 [00:00<00:19,  2.23it/s, lr=1e-5, sum_loss=0.777, loss=0.777, REAL it/s=1.130, Kt/s=0.579, val_loss=1.460]
# Epoch 3:   4%|▍         | 2/45 [00:00<00:14,  2.96it/s, lr=1e-5, sum_loss=0.777, loss=0.777, REAL it/s=1.130, Kt/s=0.579, val_loss=1.460]
# Epoch 3:   4%|▍         | 2/45 [00:00<00:14,  2.96it/s, lr=1e-5, sum_loss=1.090, loss=1.400, REAL it/s=4.310, Kt/s=2.210, val_loss=1.460]
# Epoch 3:   7%|▋         | 3/45 [00:00<00:12,  3.35it/s, lr=1e-5, sum_loss=1.090, loss=1.400, REAL it/s=4.310, Kt/s=2.210, val_loss=1.460]
# Epoch 3:   7%|▋         | 3/45 [00:00<00:12,  3.35it/s, lr=1e-5, sum_loss=1.370, loss=1.910, REAL it/s=4.660, Kt/s=2.390, val_loss=1.460]
# Epoch 3:   9%|▉         | 4/45 [00:01<00:11,  3.60it/s, lr=1e-5, sum_loss=1.370, loss=1.910, REAL it/s=4.660, Kt/s=2.390, val_loss=1.460]
# Epoch 3:   9%|▉         | 4/45 [00:01<00:11,  3.60it/s, lr=1e-5, sum_loss=1.310, loss=1.150, REAL it/s=4.560, Kt/s=2.340, val_loss=1.460]
# Epoch 3:  11%|█         | 5/45 [00:01<00:10,  3.81it/s, lr=1e-5, sum_loss=1.310, loss=1.150, REAL it/s=4.560, Kt/s=2.340, val_loss=1.460]
# Epoch 3:  11%|█         | 5/45 [00:01<00:10,  3.81it/s, lr=1e-5, sum_loss=1.400, loss=1.750, REAL it/s=4.930, Kt/s=2.530, val_loss=1.460]
# Epoch 3:  13%|█▎        | 6/45 [00:01<00:09,  3.94it/s, lr=1e-5, sum_loss=1.400, loss=1.750, REAL it/s=4.930, Kt/s=2.530, val_loss=1.460]
# Epoch 3:  13%|█▎        | 6/45 [00:01<00:09,  3.94it/s, lr=1e-5, sum_loss=1.340, loss=1.060, REAL it/s=4.810, Kt/s=2.460, val_loss=1.460]
# Epoch 3:  16%|█▌        | 7/45 [00:01<00:09,  4.05it/s, lr=1e-5, sum_loss=1.340, loss=1.060, REAL it/s=4.810, Kt/s=2.460, val_loss=1.460]
# Epoch 3:  16%|█▌        | 7/45 [00:01<00:09,  4.05it/s, lr=1e-5, sum_loss=1.360, loss=1.470, REAL it/s=4.840, Kt/s=2.480, val_loss=1.460]
# Epoch 3:  18%|█▊        | 8/45 [00:01<00:08,  4.13it/s, lr=1e-5, sum_loss=1.360, loss=1.470, REAL it/s=4.840, Kt/s=2.480, val_loss=1.460]
# Epoch 3:  18%|█▊        | 8/45 [00:01<00:08,  4.13it/s, lr=1e-5, sum_loss=1.390, loss=1.620, REAL it/s=4.720, Kt/s=2.420, val_loss=1.460]
# Epoch 3:  20%|██        | 9/45 [00:02<00:08,  4.20it/s, lr=1e-5, sum_loss=1.390, loss=1.620, REAL it/s=4.720, Kt/s=2.420, val_loss=1.460]
# Epoch 3:  20%|██        | 9/45 [00:02<00:08,  4.20it/s, lr=1e-5, sum_loss=1.450, loss=1.940, REAL it/s=4.950, Kt/s=2.530, val_loss=1.460]
# Epoch 3:  22%|██▏       | 10/45 [00:02<00:08,  4.26it/s, lr=1e-5, sum_loss=1.450, loss=1.940, REAL it/s=4.950, Kt/s=2.530, val_loss=1.460]
# Epoch 3:  22%|██▏       | 10/45 [00:02<00:08,  4.26it/s, lr=1e-5, sum_loss=1.500, loss=1.940, REAL it/s=4.850, Kt/s=2.490, val_loss=1.460]
# Epoch 3:  24%|██▍       | 11/45 [00:02<00:07,  4.31it/s, lr=1e-5, sum_loss=1.500, loss=1.940, REAL it/s=4.850, Kt/s=2.490, val_loss=1.460]
# Epoch 3:  24%|██▍       | 11/45 [00:02<00:07,  4.31it/s, lr=1e-5, sum_loss=1.440, loss=0.789, REAL it/s=4.910, Kt/s=2.520, val_loss=1.460]
# Epoch 3:  27%|██▋       | 12/45 [00:02<00:07,  4.35it/s, lr=1e-5, sum_loss=1.440, loss=0.789, REAL it/s=4.910, Kt/s=2.520, val_loss=1.460]
# Epoch 3:  27%|██▋       | 12/45 [00:02<00:07,  4.35it/s, lr=1e-5, sum_loss=1.380, loss=0.848, REAL it/s=4.800, Kt/s=2.460, val_loss=1.460]
# Epoch 3:  29%|██▉       | 13/45 [00:02<00:07,  4.39it/s, lr=1e-5, sum_loss=1.380, loss=0.848, REAL it/s=4.800, Kt/s=2.460, val_loss=1.460]
# Epoch 3:  29%|██▉       | 13/45 [00:02<00:07,  4.39it/s, lr=1e-5, sum_loss=1.450, loss=2.060, REAL it/s=4.890, Kt/s=2.510, val_loss=1.460]
# Epoch 3:  31%|███       | 14/45 [00:03<00:07,  4.42it/s, lr=1e-5, sum_loss=1.450, loss=2.060, REAL it/s=4.890, Kt/s=2.510, val_loss=1.460]
# Epoch 3:  31%|███       | 14/45 [00:03<00:07,  4.42it/s, lr=1e-5, sum_loss=1.410, loss=1.030, REAL it/s=4.870, Kt/s=2.490, val_loss=1.460]
# Epoch 8:  87%|████████▋ | 39/45 [00:08<00:01,  4.52it/s, lr=1e-5, sum_loss=0.711, loss=0.473, REAL it/s=4.440, Kt/s=2.270, val_loss=1.330]
# Epoch 8:  87%|████████▋ | 39/45 [00:08<00:01,  4.52it/s, lr=1e-5, sum_loss=0.707, loss=0.594, REAL it/s=4.130, Kt/s=2.110, val_loss=1.330]
# Epoch 8:  89%|████████▉ | 40/45 [00:08<00:01,  4.51it/s, lr=1e-5, sum_loss=0.707, loss=0.594, REAL it/s=4.130, Kt/s=2.110, val_loss=1.330]
# Epoch 8:  89%|████████▉ | 40/45 [00:08<00:01,  4.51it/s, lr=1e-5, sum_loss=0.707, loss=0.641, REAL it/s=4.040, Kt/s=2.070, val_loss=1.330]
# Epoch 8:  91%|█████████ | 41/45 [00:09<00:00,  4.51it/s, lr=1e-5, sum_loss=0.707, loss=0.641, REAL it/s=4.040, Kt/s=2.070, val_loss=1.330]
# Epoch 8:  91%|█████████ | 41/45 [00:09<00:00,  4.51it/s, lr=1e-5, sum_loss=0.699, loss=0.420, REAL it/s=4.470, Kt/s=2.290, val_loss=1.330]
# Epoch 8:  93%|█████████▎| 42/45 [00:09<00:00,  4.51it/s, lr=1e-5, sum_loss=0.699, loss=0.420, REAL it/s=4.470, Kt/s=2.290, val_loss=1.330]
# Epoch 8:  93%|█████████▎| 42/45 [00:09<00:00,  4.51it/s, lr=1e-5, sum_loss=0.707, loss=1.090, REAL it/s=4.520, Kt/s=2.310, val_loss=1.330]
# Epoch 8:  96%|█████████▌| 43/45 [00:09<00:00,  4.51it/s, lr=1e-5, sum_loss=0.707, loss=1.090, REAL it/s=4.520, Kt/s=2.310, val_loss=1.330]
# Epoch 8:  96%|█████████▌| 43/45 [00:09<00:00,  4.51it/s, lr=1e-5, sum_loss=0.715, loss=1.040, REAL it/s=4.540, Kt/s=2.320, val_loss=1.330]
# Epoch 8:  98%|█████████▊| 44/45 [00:09<00:00,  4.50it/s, lr=1e-5, sum_loss=0.715, loss=1.040, REAL it/s=4.540, Kt/s=2.320, val_loss=1.330]
# Epoch 8:  98%|█████████▊| 44/45 [00:09<00:00,  4.50it/s, lr=1e-5, sum_loss=0.715, loss=0.668, REAL it/s=4.190, Kt/s=2.150, val_loss=1.330]
# Epoch 8: 100%|██████████| 45/45 [00:10<00:00,  4.50it/s, lr=1e-5, sum_loss=0.715, loss=0.668, REAL it/s=4.190, Kt/s=2.150, val_loss=1.330]
# Epoch 8: 100%|██████████| 45/45 [00:10<00:00,  4.50it/s, lr=1e-5, sum_loss=0.711, loss=0.617, REAL it/s=4.320, Kt/s=2.210, val_loss=1.330]
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 17.98it/s]
#
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 19.11it/s]
#
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 20.04it/s]
#
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 20.81it/s]
#
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 21.30it/s]
#
#
# Epoch 8: 100%|██████████| 45/45 [00:10<00:00,  4.14it/s, lr=1e-5, sum_loss=0.711, loss=0.617, REAL it/s=4.320, Kt/s=2.210, val_loss=1.370]
# Epoch 8: 100%|██████████| 45/45 [00:10<00:00,  4.13it/s, lr=1e-5, sum_loss=0.711, loss=0.617, REAL it/s=4.320, Kt/s=2.210, val_loss=1.370]
# Epoch 8: 100%|██████████| 45/45 [00:10<00:00,  4.13it/s, lr=1e-5, sum_loss=0.711, loss=0.617, REAL it/s=4.320, Kt/s=2.210, val_loss=1.370]
#
# ⚠️ STDERR:
#  ########## work in progress ##########
# /home/re2230/rwkv-env/lib/python3.10/site-packages/deepspeed/runtime/zero/linear.py:49: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   def forward(ctx, input, weight, bias=None):
# /home/re2230/rwkv-env/lib/python3.10/site-packages/deepspeed/runtime/zero/linear.py:67: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# Using /home/re2230/.cache/torch_extensions/py310_cu126 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/re2230/.cache/torch_extensions/py310_cu126/wkv5/build.ninja...
# /home/re2230/rwkv-env/lib/python3.10/site-packages/torch/utils/cpp_extension.py:2356: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Loading extension module wkv5...
# ########## Loading /home/re2230/.cache/huggingface/hub/models--RWKV--rwkv-5-world-all-pth/snapshots/d48d1c54cf32cfdc13fca3c767998a0bf3eef8b6/RWKV-5-World-0.4B-v2-20231113-ctx4096.pth... ##########
# /home/re2230/rwkv-env/lib/python3.10/site-packages/lightning/fabric/connector.py:571: `precision=bf16` is supported for historical reasons but its usage is discouraged. Please set your precision to bf16-mixed instead!
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# initializing deepspeed distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# Enabling DeepSpeed BF16. Model parameters and inputs will be cast to `bfloat16`.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [1]
# Using /home/re2230/.cache/torch_extensions/py310_cu126 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/re2230/.cache/torch_extensions/py310_cu126/fused_adam/build.ninja...
# /home/re2230/rwkv-env/lib/python3.10/site-packages/torch/utils/cpp_extension.py:2356: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Loading extension module fused_adam...
# /home/re2230/rwkv-env/lib/python3.10/site-packages/deepspeed/ops/adam/fused_adam.py:96: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:78.)
#   self._dummy_overflow_buf = get_accelerator().IntTensor([0])
#
#   | Name      | Type             | Params | Mode
# -------------------------------------------------------
# 0 | model     | RWKV5            | 469 M  | train
# 1 | criterion | CrossEntropyLoss | 0      | train
# -------------------------------------------------------
# 8.6 M     Trainable params
# 461 M     Non-trainable params
# 469 M     Total params
# 1,879.917 Total estimated model params size (MB)
# 391       Modules in train mode
# 0         Modules in eval mode
# /home/re2230/rwkv-env/lib/python3.10/site-packages/torch/autograd/graph.py:824: UserWarning: c10d::broadcast_: an autograd kernel was not registered to the Autograd key(s) but we are trying to backprop through it. This may lead to silently incorrect behavior. This behavior is deprecated and will be removed in a future version of PyTorch. If your operator is differentiable, please ensure you have registered an autograd kernel to the correct Autograd key (e.g. DispatchKey::Autograd, DispatchKey::CompositeImplicitAutograd). If your operator is not differentiable, or to squash this warning and use the previous behavior, please register torch::CppFunction::makeFallthrough() to DispatchKey::Autograd. (Triggered internally at /pytorch/torch/csrc/autograd/autograd_not_implemented_fallback.cpp:62.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Metric val_loss improved. New best score: 1.780
# Metric val_loss improved by 0.188 >= min_delta = 0.001. New best score: 1.592
# Metric val_loss improved by 0.128 >= min_delta = 0.001. New best score: 1.464
# Metric val_loss improved by 0.108 >= min_delta = 0.001. New best score: 1.356
# Metric val_loss improved by 0.023 >= min_delta = 0.001. New best score: 1.333
# Metric val_loss improved by 0.077 >= min_delta = 0.001. New best score: 1.256
# Monitored metric val_loss did not improve in the last 3 records. Best score: 1.256. Signaling Trainer to stop.
#
# ✅ Training started successfully

# %%
import json
import matplotlib.pyplot as plt

# "loss" – general loss (probably for display)
# "t_cost" – training loss per step (token-level)
# "kt_s" – possibly token-level speed or time per step (not performance-related)

# Load data
with open("/home/re2230/Project1_RWKV_FINETUNING/out/rwkv-modbus-ft/loss_data.json") as f:
    data = [json.loads(line) for line in f if line.strip()]

# Extract loss values
steps = list(range(len(data)))
loss = [entry["loss"] for entry in data]
t_cost = [entry["t_cost"] for entry in data]

# Plot
plt.figure(figsize=(10, 5))
plt.plot(steps, loss, label="Loss")
plt.plot(steps, t_cost, label="Token Loss (t_cost)")
plt.xlabel("Step")
plt.ylabel("Loss")
plt.title("Training Loss Over Time")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import json

input_path = "/home/re2230/Project1_RWKV_FINETUNING/modbus_dataset_test.jsonl"
output_path = "/home/re2230/Project1_RWKV_FINETUNING/modbus_dataset_test_rwkv.jsonl"

with open(input_path, "r") as infile, open(output_path, "w") as outfile:
    for line in infile:
        item = json.loads(line)
        prompt = f"query: {item['query']}\n\nresponse: {item['response']}"
        outfile.write(json.dumps({"text": prompt}) + "\n")

# %%
sys.path.append("/home/re2230/Project1_RWKV_FINETUNING/RWKV-PEFT")

# %%
# Required Variables for RWKV PEFT FORMAT
os.environ["RWKV_HEAD_SIZE_A"] = "64"
os.environ["RWKV_MY_TESTING"] = "x052"
os.environ["RWKV_MY_TESTING"] = "x052"
os.environ["RWKV_TRAIN_TYPE"] = "sft"
os.environ["WKV"] = "cuda"
os.environ["FUSED_KERNEL"] = "1"

# %%
#INFERENCE JSONL FORMAT 
import torch
from types import SimpleNamespace  
from datasets import load_dataset
from transformers import AutoTokenizer
from rwkvt.peft.peft_loading import load_peft_model
import random
import jsonlines
from tqdm import tqdm

args = SimpleNamespace(
    # Required paths
    load_model="/home/re2230/.cache/huggingface/hub/models--RWKV--rwkv-5-world-all-pth/snapshots/d48d1c54cf32cfdc13fca3c767998a0bf3eef8b6/RWKV-5-World-0.4B-v2-20231113-ctx4096.pth",
    # adapter_path="/home/re2230/out/rwkv-modbus-ft/rwkv-4.pth",
    adapter_path = "/home/re2230/Project1_RWKV_FINETUNING/out/rwkv-modbus-ft/rwkv-49.pth",
    # RWKV core
    device="cuda" if torch.cuda.is_available() else "cpu",
    dtype="bf16",
    grad_cp=0,  # No gradient checkpointing during inference
    # PEFT-specific
    peft="disha",
    disha_config={"mode": "bone", "r": 32, "load": ""},
    train_parts="",
    my_pile_stage=0,
    # Required flags (even if unused)
    quant="none",
    lora_config=None,
    pissa_config=None,
    #  Required model hyperparameters
    vocab_size=65536,
    n_layer=24,
    n_embd=1024,
    ctx_len=4096,
    dim_att=1024,
    # n_layer=24,
    # n_embd=1024,
    # dim_att=768,
    dim_ffn=3584,
    head_size_a=64,
    head_size_divisor=8 
)



args, model = load_peft_model(args)
print(type(model))
model = model.to(dtype=torch.bfloat16, device="cuda").eval()

tokenizer = AutoTokenizer.from_pretrained(
    "RWKV/rwkv-5-world-3b",
    trust_remote_code=True
)

# Define Prompt Format
PROMPT = "query: {instruction}\n\nresponse:"


def generate_response(instruction, model, tokenizer, args, max_new_tokens=20):
    prompt = PROMPT.format(instruction=instruction)
    input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(args.device)
    print(tokenizer.convert_ids_to_tokens(input_ids[0]))

    with torch.no_grad():
        for _ in range(max_new_tokens):
            out = model(input_ids)
            logits = out[0] if isinstance(out, tuple) else out
            next_token = torch.argmax(logits[:, -1], dim=-1).unsqueeze(0)
            input_ids = torch.cat([input_ids, next_token], dim=1)
            if next_token.item() == tokenizer.eos_token_id:
                break

    return tokenizer.decode(input_ids[0], skip_special_tokens=True)

#Load Dataset
dataset = load_dataset("json", data_files="/home/re2230/Project1_RWKV_FINETUNING/modbus_dataset_test_rwkv.jsonl")["train"]

# Limit to first N examples (e.g., 100)
max_examples = 20
dataset = dataset.select(range(min(len(dataset), max_examples)))
results = []

import re

for item in tqdm(dataset):
    full_text = item["text"].strip()
    
    # Use regex to extract query and response
    match = re.match(r"query:\s*(.+?)\s*\n\nresponse:\s*(.+)", full_text)
    if not match:
        print("Format error:", full_text)
        continue

    query = match.group(1).strip()
    expected_response = match.group(2).strip()

    # Generate model response
    output = generate_response(query, model, tokenizer, args)

    # Save result
    results.append({
        "query": query,
        "expected_response": expected_response,
        "generated_response": output.strip()
    })


# Save predictions
with jsonlines.open("/home/re2230/Project1_RWKV_FINETUNING/inference_output/rwkv_modbus_outputs_jsonFormat.jsonl", mode='w') as writer:
    for r in results:
        writer.write(r)

print("Inference complete. Results saved to 'rwkv_modbus_outputs_jsonFormat.jsonl'")
# Out:
# RWKV_MY_TESTING x052
# Using /home/re2230/.cache/torch_extensions/py310_cu126 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/re2230/.cache/torch_extensions/py310_cu126/wkv5/build.ninja...
# /home/re2230/rwkv-env/lib/python3.10/site-packages/torch/utils/cpp_extension.py:2356: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Building extension module wkv5...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Loading extension module wkv5...
# ninja: no work to do.
# Current Python version 3.10 is below the recommended 3.11 version. It is recommended to upgrade to Python 3.11 or higher for the best experience.
# ########## Loading /home/re2230/.cache/huggingface/hub/models--RWKV--rwkv-5-world-all-pth/snapshots/d48d1c54cf32cfdc13fca3c767998a0bf3eef8b6/RWKV-5-World-0.4B-v2-20231113-ctx4096.pth... ##########
# RWKV(
#   (model): RWKV5(
#     (emb): Embedding(65536, 1024)
#     (blocks): ModuleList(
#       (0): Block(
#         (ln1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (ln2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (ln0): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (att): RWKV_TimeMix_RWKV5(
#           (time_shift): ZeroPad2d((0, 0, 1, -1))
#           (receptance): BoneLinear()
#           (key): BoneLinear()
#           (value): BoneLinear()
#           (output): BoneLinear()
#           (gate): BoneLinear()
#           (ln_x): GroupNorm(16, 1024, eps=1e-05, affine=True)
#         )
#         (ffn): RWKV_ChannelMix(
#           (time_shift): ZeroPad2d((0, 0, 1, -1))
#           (key): BoneLinear()
#           (receptance): BoneLinear()
#           (value): BoneLinear()
#         )
#       )
#       (1-23): 23 x Block(
#         (ln1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (ln2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (att): RWKV_TimeMix_RWKV5(
#           (time_shift): ZeroPad2d((0, 0, 1, -1))
#           (receptance): BoneLinear()
#           (key): BoneLinear()
#           (value): BoneLinear()
#           (output): BoneLinear()
#           (gate): BoneLinear()
#           (ln_x): GroupNorm(16, 1024, eps=1e-05, affine=True)
#         )
#         (ffn): RWKV_ChannelMix(
#           (time_shift): ZeroPad2d((0, 0, 1, -1))
#           (key): BoneLinear()
#           (receptance): BoneLinear()
#           (value): BoneLinear()
#         )
#       )
#     )
#     (ln_out): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (head): Linear(in_features=1024, out_features=65536, bias=False)
#   )
#   (criterion): FusedCrossEntropyLoss()
# )
# <class 'rwkvt.lightning_train.light_rwkv.RWKV'>
# Generating train split: 0 examples [00:00, ? examples/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# ['<s>', 'query', ':', ' 02', '1', 'd', '00', '00', '00', '06', '00', '03', 'fff', 'd', '00', '02', '\n\n', 'response', ':']
#   5%|▌         | 1/20 [00:01<00:22,  1.20s/it]
# ['<s>', 'query', ':', ' 01', '2', 'c', '00', '00', '00', '06', '00', '05', 'fff', 'df', 'f', '00', '\n\n', 'response', ':']
#  10%|█         | 2/20 [00:02<00:18,  1.04s/it]
# ['<s>', 'query', ':', ' 03', 'eb', '00', '00', '00', '06', '00', '05', '00', '09', '00', '00', '\n\n', 'response', ':']
#  15%|█▌        | 3/20 [00:02<00:16,  1.04it/s]
# ['<s>', 'query', ':', ' 04', '5', 'd', '00', '00', '00', '06', '00', '01', 'fff', 'e', '00', '01', '\n\n', 'response', ':']
#  20%|██        | 4/20 [00:03<00:14,  1.08it/s]
# ['<s>', 'query', ':', ' 06', '10', '00', '00', '00', '0', 'd', '00', '10', '00', '28', '00', '03', '06', '00', '00', 'ffff', '00', '00', '\n\n', 'response', ':']
#  25%|██▌       | 5/20 [00:04<00:13,  1.09it/s]
# ['<s>', 'query', ':', ' 05', '8', 'd', '00', '00', '00', '06', '00', '01', '00', '28', '00', '02', '\n\n', 'response', ':']
#  30%|███       | 6/20 [00:05<00:12,  1.12it/s]
# ['<s>', 'query', ':', ' 03', '20', '00', '00', '00', '06', '00', '03', '00', '28', '00', '01', '\n\n', 'response', ':']
#  35%|███▌      | 7/20 [00:06<00:11,  1.11it/s]
# ['<s>', 'query', ':', ' 02', '3', 'a', '00', '00', '00', '06', '00', '03', 'fff', 'e', '00', '01', '\n\n', 'response', ':']
#  40%|████      | 8/20 [00:07<00:10,  1.11it/s]
# ['<s>', 'query', ':', ' 03', '82', '00', '00', '00', '0', 'd', '00', '10', '00', '25', '00', '03', '06', '00', '00', 'a', '99', '4', 'a', '99', '4', '\n\n', 'response', ':']
#  45%|████▌     | 9/20 [00:08<00:09,  1.14it/s]
# ['<s>', 'query', ':', ' 02', '53', '00', '00', '00', '06', '00', '03', '00', '00', '00', '02', '\n\n', 'response', ':']
#  50%|█████     | 10/20 [00:09<00:08,  1.16it/s]
# ['<s>', 'query', ':', ' 04', 'd', '20', '00', '00', '00', '60', '00', '50', '02', '8', 'ff', '00', '\n\n', 'response', ':']
#  55%|█████▌    | 11/20 [00:10<00:08,  1.04it/s]
# ['<s>', 'query', ':', ' 05', '46', '00', '00', '00', '06', '00', '03', '00', '00', '00', '01', '\n\n', 'response', ':']
#  60%|██████    | 12/20 [00:11<00:07,  1.10it/s]
# ['<s>', 'query', ':', ' 02', 'ca', '00', '00', '00', '06', '00', '01', '00', '28', '00', '02', '\n\n', 'response', ':']
#  65%|██████▌   | 13/20 [00:12<00:06,  1.09it/s]
# ['<s>', 'query', ':', ' 03', '4', 'f', '00', '00', '00', '06', '00', '01', 'eb', '18', '00', '02', '\n\n', 'response', ':']
#  70%|███████   | 14/20 [00:12<00:05,  1.06it/s]
# ['<s>', 'query', ':', ' 00', '56', '00', '00', '00', '06', '00', '03', '00', '25', '00', '02', '\n\n', 'response', ':']
#  75%|███████▌  | 15/20 [00:13<00:04,  1.06it/s]
# ['<s>', 'query', ':', ' 05', 'fe', '00', '00', '00', '06', '00', '03', 'cab', '30', '00', '2', '\n\n', 'response', ':']
#  80%|████████  | 16/20 [00:14<00:03,  1.11it/s]
# ['<s>', 'query', ':', ' 01', 'a', '20', '00', '00', '00', '60', '00', '30', '01', '20', '00', '2', '\n\n', 'response', ':']
#  85%|████████▌ | 17/20 [00:15<00:02,  1.05it/s]
# ['<s>', 'query', ':', ' 05', '66', '00', '00', '00', '06', '00', '01', 'fff', 'e', '00', '01', '\n\n', 'response', ':']
#  90%|█████████ | 18/20 [00:16<00:01,  1.07it/s]
# ['<s>', 'query', ':', ' 05', '0', 'c', '00', '00', '00', '0', 'd', '00', '10', 'fff', 'd', '00', '03', '06', 'ffffffff', '83', '18', '\n\n', 'response', ':']
#  95%|█████████▌| 19/20 [00:17<00:00,  1.06it/s]
# ['<s>', 'query', ':', ' 04', '47', '00', '00', '00', '06', '00', '01', '00', '28', '00', '02', '\n\n', 'response', ':']
# 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# Inference complete. Results saved to 'rwkv_modbus_outputs_1.jsonl'

# %%
#EVALUATING INFERENCE

import jsonlines

def hex_accuracy(pred, target):
    pred_bytes = [pred[i:i+2] for i in range(0, len(pred), 2)]
    target_bytes = [target[i:i+2] for i in range(0, len(target), 2)]
    if not target_bytes:
        return 0.0
    correct = sum(p == t for p, t in zip(pred_bytes, target_bytes))
    return correct / len(target_bytes)

accuracies = []

with jsonlines.open("/home/re2230/Project1_RWKV_FINETUNING/inference_output/rwkv_modbus_outputs_jsonFormat.jsonl") as reader:
    for entry in reader:
        acc = hex_accuracy(entry["generated_response"], entry["expected_response"])
        accuracies.append(acc)

print(f"Test Byte Accuracy: {sum(accuracies)/len(accuracies):.2%}")
# Out:
# ✅ Test Byte Accuracy: 12.24%

# %%
#INFERENCE JSONL FORMAT AND TIME OF INFERENCE 

import torch
from types import SimpleNamespace  # 🔄 Replacement for InferenceArgs
from datasets import load_dataset
from transformers import AutoTokenizer
from rwkvt.peft.peft_loading import load_peft_model
import random
import jsonlines
from tqdm import tqdm
import time

results = []
total_time = 0
num_queries = 0

args = SimpleNamespace(
    # Required paths
    load_model="/home/re2230/.cache/huggingface/hub/models--RWKV--rwkv-5-world-all-pth/snapshots/d48d1c54cf32cfdc13fca3c767998a0bf3eef8b6/RWKV-5-World-0.4B-v2-20231113-ctx4096.pth",
    adapter_path = "/home/re2230/Project1_RWKV_FINETUNING/out/rwkv-modbus-ft/rwkv-49.pth",
    # RWKV core
    device="cuda" if torch.cuda.is_available() else "cpu",
    dtype="bf16",
    grad_cp=0,  # No gradient checkpointing during inference
    # PEFT-specific
    peft="disha",
    disha_config={"mode": "bone", "r": 32, "load": ""},
    train_parts="",
    my_pile_stage=0,
    # Required flags (even if unused)
    quant="none",
    lora_config=None,
    pissa_config=None,
    # Required model hyperparameters
    vocab_size=65536,
    n_layer=24,
    n_embd=1024,
    ctx_len=4096,
    dim_att=1024,
    dim_ffn=3584,
    head_size_a=64,
    head_size_divisor=8 
)


args, model = load_peft_model(args)
print(type(model))

model = model.to(dtype=torch.bfloat16, device="cuda").eval()

tokenizer = AutoTokenizer.from_pretrained(
    "RWKV/rwkv-5-world-3b",
    trust_remote_code=True
)

# Define Prompt Format

prompt = "query: {instruction}\n\nresponse:"

def generate_response(instruction, model, tokenizer, args, max_new_tokens=10):
    prompt = PROMPT.format(instruction=instruction)
    input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(args.device)
    print(tokenizer.convert_ids_to_tokens(input_ids[0]))

    with torch.no_grad():
        for _ in range(max_new_tokens):
            out = model(input_ids)
            logits = out[0] if isinstance(out, tuple) else out
            next_token = torch.argmax(logits[:, -1], dim=-1).unsqueeze(0)
            input_ids = torch.cat([input_ids, next_token], dim=1)
            if next_token.item() == tokenizer.eos_token_id:
                break

    return tokenizer.decode(input_ids[0], skip_special_tokens=True)

#Load Dataset

dataset = load_dataset("json", data_files="/home/re2230/Project1_RWKV_FINETUNING/modbus_dataset_test_rwkv.jsonl")["train"]
# Limit to first N examples (e.g., 100)
max_examples = 20
dataset = dataset.select(range(min(len(dataset), max_examples)))
results = []

import re

for item in tqdm(dataset):
    full_text = item["text"].strip()
    
    # Use regex to extract query and response
    match = re.match(r"query:\s*(.+?)\s*\n\nresponse:\s*(.+)", full_text)
    if not match:
        print("❌ Format error:", full_text)
        continue

    query = match.group(1).strip()
    expected_response = match.group(2).strip()

    start_time = time.time()
    output = generate_response(query, model, tokenizer, args)  
    elapsed = time.time() - start_time
    
    # Save result
    results.append({
        "query": query,
        "expected_response": expected_response,
        "generated_response": output.strip()
    })

    total_time += elapsed
    num_queries += 1

avg_time = total_time / num_queries
print(f"Inference complete. Avg time per query: {avg_time:.4f} seconds")


# Save Predictions
with jsonlines.open("/home/re2230/Project1_RWKV_FINETUNING/inference_output/rwkv_modbus_outputs_time.jsonl", mode='w') as writer:
    for r in results:
        writer.write(r)

print("✅ Inference complete. Results saved to 'rwkv_modbus_outputs_time.jsonl'")
# Out:
# ########## Loading /home/re2230/.cache/huggingface/hub/models--RWKV--rwkv-5-world-all-pth/snapshots/d48d1c54cf32cfdc13fca3c767998a0bf3eef8b6/RWKV-5-World-0.4B-v2-20231113-ctx4096.pth... ##########
# RWKV(
#   (model): RWKV5(
#     (emb): Embedding(65536, 1024)
#     (blocks): ModuleList(
#       (0): Block(
#         (ln1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (ln2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (ln0): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (att): RWKV_TimeMix_RWKV5(
#           (time_shift): ZeroPad2d((0, 0, 1, -1))
#           (receptance): BoneLinear()
#           (key): BoneLinear()
#           (value): BoneLinear()
#           (output): BoneLinear()
#           (gate): BoneLinear()
#           (ln_x): GroupNorm(16, 1024, eps=1e-05, affine=True)
#         )
#         (ffn): RWKV_ChannelMix(
#           (time_shift): ZeroPad2d((0, 0, 1, -1))
#           (key): BoneLinear()
#           (receptance): BoneLinear()
#           (value): BoneLinear()
#         )
#       )
#       (1-23): 23 x Block(
#         (ln1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (ln2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (att): RWKV_TimeMix_RWKV5(
#           (time_shift): ZeroPad2d((0, 0, 1, -1))
#           (receptance): BoneLinear()
#           (key): BoneLinear()
#           (value): BoneLinear()
#           (output): BoneLinear()
#           (gate): BoneLinear()
#           (ln_x): GroupNorm(16, 1024, eps=1e-05, affine=True)
#         )
#         (ffn): RWKV_ChannelMix(
#           (time_shift): ZeroPad2d((0, 0, 1, -1))
#           (key): BoneLinear()
#           (receptance): BoneLinear()
#           (value): BoneLinear()
#         )
#       )
#     )
#     (ln_out): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (head): Linear(in_features=1024, out_features=65536, bias=False)
#   )
#   (criterion): FusedCrossEntropyLoss()
# )
# <class 'rwkvt.lightning_train.light_rwkv.RWKV'>
#   0%|          | 0/20 [00:00<?, ?it/s]
# ['<s>', 'query', ':', ' 02', '1', 'd', '00', '00', '00', '06', '00', '03', 'fff', 'd', '00', '02', '\n\n', 'response', ':']
#   5%|▌         | 1/20 [00:00<00:13,  1.41it/s]
# ['<s>', 'query', ':', ' 01', '2', 'c', '00', '00', '00', '06', '00', '05', 'fff', 'df', 'f', '00', '\n\n', 'response', ':']
#  10%|█         | 2/20 [00:01<00:12,  1.45it/s]
# ['<s>', 'query', ':', ' 03', 'eb', '00', '00', '00', '06', '00', '05', '00', '09', '00', '00', '\n\n', 'response', ':']
#  15%|█▌        | 3/20 [00:02<00:12,  1.41it/s]
# ['<s>', 'query', ':', ' 04', '5', 'd', '00', '00', '00', '06', '00', '01', 'fff', 'e', '00', '01', '\n\n', 'response', ':']
#  20%|██        | 4/20 [00:02<00:10,  1.56it/s]
# ['<s>', 'query', ':', ' 06', '10', '00', '00', '00', '0', 'd', '00', '10', '00', '28', '00', '03', '06', '00', '00', 'ffff', '00', '00', '\n\n', 'response', ':']
#  25%|██▌       | 5/20 [00:03<00:09,  1.65it/s]
# ['<s>', 'query', ':', ' 05', '8', 'd', '00', '00', '00', '06', '00', '01', '00', '28', '00', '02', '\n\n', 'response', ':']
#  30%|███       | 6/20 [00:03<00:08,  1.67it/s]
# ['<s>', 'query', ':', ' 03', '20', '00', '00', '00', '06', '00', '03', '00', '28', '00', '01', '\n\n', 'response', ':']
#  35%|███▌      | 7/20 [00:04<00:07,  1.74it/s]
# ['<s>', 'query', ':', ' 02', '3', 'a', '00', '00', '00', '06', '00', '03', 'fff', 'e', '00', '01', '\n\n', 'response', ':']
#  40%|████      | 8/20 [00:05<00:07,  1.58it/s]
# ['<s>', 'query', ':', ' 03', '82', '00', '00', '00', '0', 'd', '00', '10', '00', '25', '00', '03', '06', '00', '00', 'a', '99', '4', 'a', '99', '4', '\n\n', 'response', ':']
#  45%|████▌     | 9/20 [00:05<00:06,  1.69it/s]
# ['<s>', 'query', ':', ' 02', '53', '00', '00', '00', '06', '00', '03', '00', '00', '00', '02', '\n\n', 'response', ':']
#  50%|█████     | 10/20 [00:06<00:05,  1.74it/s]
# ['<s>', 'query', ':', ' 04', 'd', '20', '00', '00', '00', '60', '00', '50', '02', '8', 'ff', '00', '\n\n', 'response', ':']
#  55%|█████▌    | 11/20 [00:06<00:04,  1.80it/s]
# ['<s>', 'query', ':', ' 05', '46', '00', '00', '00', '06', '00', '03', '00', '00', '00', '01', '\n\n', 'response', ':']
#  60%|██████    | 12/20 [00:07<00:04,  1.84it/s]
# ['<s>', 'query', ':', ' 02', 'ca', '00', '00', '00', '06', '00', '01', '00', '28', '00', '02', '\n\n', 'response', ':']
#  65%|██████▌   | 13/20 [00:07<00:03,  1.84it/s]
# ['<s>', 'query', ':', ' 03', '4', 'f', '00', '00', '00', '06', '00', '01', 'eb', '18', '00', '02', '\n\n', 'response', ':']
#  70%|███████   | 14/20 [00:08<00:03,  1.70it/s]
# ['<s>', 'query', ':', ' 00', '56', '00', '00', '00', '06', '00', '03', '00', '25', '00', '02', '\n\n', 'response', ':']
#  75%|███████▌  | 15/20 [00:08<00:02,  1.75it/s]
# ['<s>', 'query', ':', ' 05', 'fe', '00', '00', '00', '06', '00', '03', 'cab', '30', '00', '2', '\n\n', 'response', ':']
#  80%|████████  | 16/20 [00:09<00:02,  1.71it/s]
# ['<s>', 'query', ':', ' 01', 'a', '20', '00', '00', '00', '60', '00', '30', '01', '20', '00', '2', '\n\n', 'response', ':']
#  85%|████████▌ | 17/20 [00:10<00:01,  1.72it/s]
# ['<s>', 'query', ':', ' 05', '66', '00', '00', '00', '06', '00', '01', 'fff', 'e', '00', '01', '\n\n', 'response', ':']
#  90%|█████████ | 18/20 [00:10<00:01,  1.72it/s]
# ['<s>', 'query', ':', ' 05', '0', 'c', '00', '00', '00', '0', 'd', '00', '10', 'fff', 'd', '00', '03', '06', 'ffffffff', '83', '18', '\n\n', 'response', ':']
#  95%|█████████▌| 19/20 [00:11<00:00,  1.75it/s]
# ['<s>', 'query', ':', ' 04', '47', '00', '00', '00', '06', '00', '01', '00', '28', '00', '02', '\n\n', 'response', ':']
# 100%|██████████| 20/20 [00:11<00:00,  1.67it/s]
# Inference complete. Avg time per query: 0.5937 seconds
# ✅ Inference complete. Results saved to 'rwkv_modbus_outputs.jsonl'
